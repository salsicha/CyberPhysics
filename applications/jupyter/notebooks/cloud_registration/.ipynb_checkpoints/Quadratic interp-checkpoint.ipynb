# %%
x = [3, 4, 5]
y = [1, 2, 4]


P_0 = lambda x_in: (x_in - x[1]) * (x_in - x[2]) / ((x[0] - x[1]) * (x[0] - x[2]))
P_1 = lambda x_in: (x_in - x[0]) * (x_in - x[2]) / ((x[1] - x[0]) * (x[1] - x[2]))
P_2 = lambda x_in: (x_in - x[0]) * (x_in - x[1]) / ((x[2] - x[0]) * (x[2] - x[1]))


x_interp = 4.5

Interp = y[0] * P_0(x_interp) + y[1] * P_1(x_interp) + y[2] * P_2(x_interp)

print(Interp)
# Out:
# 2.875
